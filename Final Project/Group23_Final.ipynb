# %% [markdown]
# # Final Project

# %% [markdown]
# ## Best Neighborhood in Pittsburgh PA

# %% [markdown]
# **Our Metric for determining the best neighborhood is walkability**

# %% [markdown]
# **First lets import all the nessesary tools**

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import fpsnippets

# %% [markdown]
# **First Dataset (Misael)**

# %% [markdown]
# ##### Lets import all the data that contains information on locations of convenience Store/Super Market

# %%
df = pd.read_csv("data-conveniencesupermarkets.csv")
df.head()
# Out:
#       Client ID                               Name  \
# 0  201211150002                        Avalon Fuel
# 1  201511040005     Ez Energy #303/7Eleven #36183H
# 2  201212130003  EZ Energy #311 / 7 Eleven #36191H
# 3  201211190006     Getgo #3646 / Crafton - Ingram
# 4         53583                   Mt NeBlvd Texaco
#
#                        Legal Name  Start Date Street #  \
# 0             Avalon Fuel Company  10/26/2012      901
# 1  Neelkanth Ansh Enterprises Inc  10/26/2015      209
# 2                    7 Eleven Inc   12/3/2012     8136
# 3                 Giant Eagle Inc  11/15/2012      280
# 4                Mt NeBlvd Texaco    6/2/1995     1706
#
#                       Street Name State      Zip        Lat        Lon  \
# 0                 Ohio River Blvd    PA  15202.0  40.495759 -80.066508
# 1                 Ohio River Blvd    PA  15143.0  40.545418 -80.194152
# 2                 Ohio River Blvd    PA  15202.0  40.510522 -80.094268
# 3  Crafton Ingram Shopping circle    PA  15205.0  41.203322 -77.194525
# 4                      Mt Nebo Rd    PA  15143.0  40.553281 -80.109158
#
#    Accuracy           Category
# 0       9.0  Convenience Store
# 1       9.0  Convenience Store
# 2       9.0  Convenience Store
# 3       3.0  Convenience Store
# 4       8.0  Convenience Store

# %% [markdown]
# ##### Now lets use the the coordinates given to use to locate which neighborhood the stores are located in.

# %%
for id, row in df.iterrows():
        df.loc[id, "Neighborhood"] = fpsnippets.geo_to_neighborhood(row[8],row[9])
df.head()
# Out:
#       Client ID                               Name  \
# 0  201211150002                        Avalon Fuel
# 1  201511040005     Ez Energy #303/7Eleven #36183H
# 2  201212130003  EZ Energy #311 / 7 Eleven #36191H
# 3  201211190006     Getgo #3646 / Crafton - Ingram
# 4         53583                   Mt NeBlvd Texaco
#
#                        Legal Name  Start Date Street #  \
# 0             Avalon Fuel Company  10/26/2012      901
# 1  Neelkanth Ansh Enterprises Inc  10/26/2015      209
# 2                    7 Eleven Inc   12/3/2012     8136
# 3                 Giant Eagle Inc  11/15/2012      280
# 4                Mt NeBlvd Texaco    6/2/1995     1706
#
#                       Street Name State      Zip        Lat        Lon  \
# 0                 Ohio River Blvd    PA  15202.0  40.495759 -80.066508
# 1                 Ohio River Blvd    PA  15143.0  40.545418 -80.194152
# 2                 Ohio River Blvd    PA  15202.0  40.510522 -80.094268
# 3  Crafton Ingram Shopping circle    PA  15205.0  41.203322 -77.194525
# 4                      Mt Nebo Rd    PA  15143.0  40.553281 -80.109158
#
#    Accuracy           Category Neighborhood
# 0       9.0  Convenience Store          NaN
# 1       9.0  Convenience Store          NaN
# 2       9.0  Convenience Store          NaN
# 3       3.0  Convenience Store          NaN
# 4       8.0  Convenience Store          NaN

# %% [markdown]
# ##### We have indicated the neighborhood that each store is located in. But some stores neighborhood could not be located so we will drop them from the list.

# %%
df.dropna(axis=0, subset=['Neighborhood'])
# Out:
#         Client ID                             Name             Legal Name  \
# 7           52845  Sunoco A Plus Mini Market #8154                    NaN
# 14   200912080002                 7 Eleven #36143A                    NaN
# 19   201209070008                 American Natural  Desdemona Holdings LP
# 22   200809180008                    Bett's Market                    NaN
# 29          37867                     Co Go's #805                Co Go's
# ..            ...                              ...                    ...
# 657         34765                   Gorkhali Store                    NaN
# 660         30265              Subha Laxmi Grocery                    NaN
# 666  201110130006                         Aldi #79               Aldi Inc
# 667  201210250002                         Aldi #80               Aldi Inc
# 670  200802270004                   Wal-Mart #5339    Wal-Mart Stores Inc
#
#      Start Date Street #     Street Name State      Zip        Lat        Lon  \
# 7    10/25/1994     5204     Interbo Ave    PA  15207.0  40.370214 -79.913195
# 14   11/17/2009      601         Penn Av    PA  15222.0  40.442813 -80.001884
# 19    8/23/2012       73       Carson St    PA  15219.0  40.430917 -80.001402
# 22     9/8/2008      819    Brushton Ave    PA  15208.0  40.455264 -79.888216
# 29    5/17/1984     4071  Beechwood Blvd    PA  15217.0  40.427102 -79.938593
# ..          ...      ...             ...   ...      ...        ...        ...
# 657   5/19/2014     2116  Brownsville Rd    PA  15210.0  40.392709 -79.987056
# 660   5/21/2014     2950  Brownsville Rd    PA  15227.0  40.381398 -79.976585
# 666  10/23/2012     2628       Carson St    PA  15203.0  40.426914 -79.967530
# 667    5/8/2013     5631       Baum Blvd    PA  15213.0  40.458291 -79.935066
# 670  10/20/2003      877     Freeport Rd    PA  15238.0  40.488181 -79.888875
#
#      Accuracy           Category               Neighborhood
# 7         9.0  Convenience Store              Lincoln Place
# 14        8.0  Convenience Store  Central Business District
# 19        8.0  Convenience Store                South Shore
# 22        8.0  Convenience Store             Homewood South
# 29        8.0  Convenience Store                 Greenfield
# ..        ...                ...                        ...
# 657       9.0        Supermarket                    Carrick
# 660       9.0        Supermarket                    Carrick
# 666       9.0        Supermarket           South Side Flats
# 667       9.0        Supermarket                 Friendship
# 670       9.0        Supermarket   Lincoln-Lemington-Belmar
#
# [190 rows x 13 columns]

# %% [markdown]
# ##### That looks much better!!!

# %% [markdown]
# ##### Now lets plot the locations to figure out which neighborhood has the most convenience Store/Super Market

# %%
plt.style.use('seaborn-dark')
df["Neighborhood"].value_counts().sort_index().plot(kind='bar', rot=-90,figsize=(15, 8))

# %% [markdown]
# ##### Now lets rank the Neighborhoods by amount of store, Since there are many Neighborhoods lets Normalize the data to give us a more accurate rating.

# %%
neighborhood_counts = df["Neighborhood"].value_counts()

min_count = neighborhood_counts.min()
max_count = neighborhood_counts.max()

rating_range = 10 - 1
normalize_count = (neighborhood_counts - min_count) / (max_count - min_count) * rating_range + 1

neighborhood_ratings = normalize_count.to_dict()
df['Rating'] = df['Neighborhood'].map(neighborhood_ratings)
df.dropna(axis=0, subset=['Rating'])
# Out:
#         Client ID                             Name             Legal Name  \
# 7           52845  Sunoco A Plus Mini Market #8154                    NaN
# 14   200912080002                 7 Eleven #36143A                    NaN
# 19   201209070008                 American Natural  Desdemona Holdings LP
# 22   200809180008                    Bett's Market                    NaN
# 29          37867                     Co Go's #805                Co Go's
# ..            ...                              ...                    ...
# 657         34765                   Gorkhali Store                    NaN
# 660         30265              Subha Laxmi Grocery                    NaN
# 666  201110130006                         Aldi #79               Aldi Inc
# 667  201210250002                         Aldi #80               Aldi Inc
# 670  200802270004                   Wal-Mart #5339    Wal-Mart Stores Inc
#
#      Start Date Street #     Street Name State      Zip        Lat        Lon  \
# 7    10/25/1994     5204     Interbo Ave    PA  15207.0  40.370214 -79.913195
# 14   11/17/2009      601         Penn Av    PA  15222.0  40.442813 -80.001884
# 19    8/23/2012       73       Carson St    PA  15219.0  40.430917 -80.001402
# 22     9/8/2008      819    Brushton Ave    PA  15208.0  40.455264 -79.888216
# 29    5/17/1984     4071  Beechwood Blvd    PA  15217.0  40.427102 -79.938593
# ..          ...      ...             ...   ...      ...        ...        ...
# 657   5/19/2014     2116  Brownsville Rd    PA  15210.0  40.392709 -79.987056
# 660   5/21/2014     2950  Brownsville Rd    PA  15227.0  40.381398 -79.976585
# 666  10/23/2012     2628       Carson St    PA  15203.0  40.426914 -79.967530
# 667    5/8/2013     5631       Baum Blvd    PA  15213.0  40.458291 -79.935066
# 670  10/20/2003      877     Freeport Rd    PA  15238.0  40.488181 -79.888875
#
#      Accuracy           Category               Neighborhood   Rating
# 7         9.0  Convenience Store              Lincoln Place   2.1250
# 14        8.0  Convenience Store  Central Business District  10.0000
# 19        8.0  Convenience Store                South Shore   1.0000
# 22        8.0  Convenience Store             Homewood South   2.1250
# 29        8.0  Convenience Store                 Greenfield   3.2500
# ..        ...                ...                        ...      ...
# 657       9.0        Supermarket                    Carrick   5.5000
# 660       9.0        Supermarket                    Carrick   5.5000
# 666       9.0        Supermarket           South Side Flats   4.9375
# 667       9.0        Supermarket                 Friendship   1.5625
# 670       9.0        Supermarket   Lincoln-Lemington-Belmar   1.5625
#
# [190 rows x 14 columns]

# %% [markdown]
# ##### Now lets filter out any repeating neighborhoods.

# %%
df_filtered = df.drop_duplicates(subset='Neighborhood')
df_filtered = df_filtered.dropna(axis=0, subset=['Rating']).head(30)
print(df_filtered[['Neighborhood', 'Rating']].sort_values(by='Rating', ascending=False).head(64))
# Out:
#                   Neighborhood   Rating
# 14   Central Business District  10.0000
# 167                 Bloomfield   6.6250
# 169                    Carrick   5.5000
# 38                   Shadyside   5.5000
# 71              Strip District   5.5000
# 75            South Side Flats   4.9375
# 93                   Brookline   4.3750
# 112            Central Oakland   3.8125
# 29                  Greenfield   3.2500
# 125              North Oakland   3.2500
# 62         Squirrel Hill South   3.2500
# 139           Crawford-Roberts   2.6875
# 90                   Troy Hill   2.1250
# 140          Central Northside   2.1250
# 7                Lincoln Place   2.1250
# 68               Spring Garden   2.1250
# 22              Homewood South   2.1250
# 82                    Garfield   1.5625
# 114        Upper Lawrenceville   1.5625
# 61             Terrace Village   1.5625
# 147                Morningside   1.5625
# 151                Middle Hill   1.5625
# 174                 Banksville   1.5625
# 128                    Chateau   1.0000
# 41                  East Hills   1.0000
# 34           Northview Heights   1.0000
# 142                Polish Hill   1.0000
# 19                 South Shore   1.0000
# 173                Summer Hill   1.0000
# 181              Highland Park   1.0000

# %% [markdown]
# ### YAAAAAAAAAAAAA!!!!!!!!!!

# %% [markdown]
# #### Now we are done!!!!!!

# %% [markdown]
# ### Misael's Conclusion:

# %% [markdown]
# After finding the ratings for each of the neighborhoods in Pittsburgh, we can conclude that Central Business District(Downtown I think) has the most conveince store/ Supermarkets. Threfore if you are walking about and need to buy groceries or something quick to eat you'll have the best luck of finding something within walking distance in Central Business District.

# %%
import numpy as np
import shapely 
import seaborn as sns

# %%
parks = gpd.read_file("parks/PGHWebParks.shp")
parks.plot()

# %%
parkz = pd.read_csv("parks/parks.csv")
num_parks = parkz.groupby("sector").sum()["acreage"]
num_parks.head()
num_parks.sort_values(ascending=False)
# Out:
# sector
# 10.0    1079.722325
# 8.0      662.504800
# 12.0     421.592659
# 6.0      349.570826
# 5.0      319.957029
# 2.0      311.913053
# 9.0      165.063443
# 4.0      118.353087
# 7.0      102.364840
# 3.0       75.968822
# 15.0      73.774938
# 13.0      72.403109
# 16.0      57.767179
# 11.0      39.536096
# 1.0       31.928987
# 14.0       6.541371
# Name: acreage, dtype: float64

# %%
neighborhoods = gpd.read_file("Neighborhoods/Neighborhoods_.shp") 
neighborhoods.plot()

# %%
parks["center"] = parks["geometry"].centroid
parks["lat"] = parks["center"].x
parks["long"] = parks["center"].y
parks.head()
# Out:
# <ipython-input-50-89d1a44c3a13>:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   parks["center"] = parks["geometry"].centroid
#    OBJECTID_1  objectid   acreage           sqft          final_cat type_  \
# 0        1202      36.0  0.959034   41775.367101  Neighborhood Park    NP
# 1        1203     198.0  2.060117   89738.347520  Neighborhood Park    NP
# 2        1204     158.0  0.468682   20415.724875  Neighborhood Park    NP
# 3        1205      72.0  1.955430   85178.182207  Neighborhood Park    NP
# 4        1206      87.0  5.108070  222506.623799  Neighborhood Park    NP
#
#   sector         origpkname                       updatepknm  \
# 0     15  Cliffside Parklet               August Wilson Park
# 1      2        Young Field                 Young Field Park
# 2      8       Revenue Park  Roland Lockridge Community Park
# 3     12    Friendship Park                  Friendship Park
# 4     12   Heths Playground                      Heth's Park
#
#                         alterntnam  ...  last_edi_1         maintenanc  \
# 0                   Cliffside Park  ...  2023-08-02   Parks - Schenley
# 1                       Young Park  ...  2023-08-02  Parks - Riverview
# 2  Roland Lockridge Community Park  ...  2023-08-02      Parks - Frick
# 3                  Friendship Park  ...  2023-08-02   Parks - Highland
# 4                      Heth's Park  ...  2023-08-02   Parks - Highland
#
#               dpw_ac                            GlobalID_1    Shape__Are  \
# 0  0.959034302188266  f781af9c-9ec2-4b5e-b5c5-9cc21608635c   6709.199219
# 1   2.06011722852731  659c4c55-50fc-4883-8606-76f029fcca47  14423.417969
# 2  0.468682427403543  04e61cab-bea6-47dd-964a-0723197726cf   3273.722656
# 3   1.95542981911229  22563a68-61d3-46f3-9d5c-4558ee12be1f  13686.265625
# 4   5.10806964711613  b5b34833-e1d5-430f-afcc-40a1670d545d  35767.898438
#
#    Shape__Len                                           geometry  \
# 0  390.397012  POLYGON ((-79.98614 40.44665, -79.98613 40.446...
# 1  511.980181  POLYGON ((-80.03313 40.47289, -80.03314 40.473...
# 2  236.488235  POLYGON ((-79.92039 40.39402, -79.92047 40.393...
# 3  760.982871  POLYGON ((-79.94539 40.46264, -79.94486 40.462...
# 4  875.156997  POLYGON ((-79.92675 40.47832, -79.92722 40.477...
#
#                        center        lat       long
# 0  POINT (-79.98570 40.44658) -79.985699  40.446583
# 1  POINT (-80.03249 40.47296) -80.032487  40.472955
# 2  POINT (-79.92074 40.39394) -79.920739  40.393940
# 3  POINT (-79.94616 40.46257) -79.946165  40.462570
# 4  POINT (-79.92767 40.47768) -79.927670  40.477683
#
# [5 rows x 26 columns]

# %%
def getNeighborhood():
    for id, row in parks.iterrows():
        print(fpsnippets.geo_to_neighborhood(row[-1],row[-2]))

#getNeighborhood()

def addNeighborhood():
    for id, row in parks.iterrows():
        parks.loc[id, "neighborhood"] = (fpsnippets.geo_to_neighborhood(row[-1],row[-2]))
addNeighborhood()

parks.head()
# Out:
#    OBJECTID_1  objectid   acreage           sqft          final_cat type_  \
# 0        1202      36.0  0.959034   41775.367101  Neighborhood Park    NP
# 1        1203     198.0  2.060117   89738.347520  Neighborhood Park    NP
# 2        1204     158.0  0.468682   20415.724875  Neighborhood Park    NP
# 3        1205      72.0  1.955430   85178.182207  Neighborhood Park    NP
# 4        1206      87.0  5.108070  222506.623799  Neighborhood Park    NP
#
#   sector         origpkname                       updatepknm  \
# 0     15  Cliffside Parklet               August Wilson Park
# 1      2        Young Field                 Young Field Park
# 2      8       Revenue Park  Roland Lockridge Community Park
# 3     12    Friendship Park                  Friendship Park
# 4     12   Heths Playground                      Heth's Park
#
#                         alterntnam  ...         maintenanc             dpw_ac  \
# 0                   Cliffside Park  ...   Parks - Schenley  0.959034302188266
# 1                       Young Park  ...  Parks - Riverview   2.06011722852731
# 2  Roland Lockridge Community Park  ...      Parks - Frick  0.468682427403543
# 3                  Friendship Park  ...   Parks - Highland   1.95542981911229
# 4                      Heth's Park  ...   Parks - Highland   5.10806964711613
#
#                              GlobalID_1    Shape__Are  Shape__Len  \
# 0  f781af9c-9ec2-4b5e-b5c5-9cc21608635c   6709.199219  390.397012
# 1  659c4c55-50fc-4883-8606-76f029fcca47  14423.417969  511.980181
# 2  04e61cab-bea6-47dd-964a-0723197726cf   3273.722656  236.488235
# 3  22563a68-61d3-46f3-9d5c-4558ee12be1f  13686.265625  760.982871
# 4  b5b34833-e1d5-430f-afcc-40a1670d545d  35767.898438  875.156997
#
#                                             geometry  \
# 0  POLYGON ((-79.98614 40.44665, -79.98613 40.446...
# 1  POLYGON ((-80.03313 40.47289, -80.03314 40.473...
# 2  POLYGON ((-79.92039 40.39402, -79.92047 40.393...
# 3  POLYGON ((-79.94539 40.46264, -79.94486 40.462...
# 4  POLYGON ((-79.92675 40.47832, -79.92722 40.477...
#
#                        center        lat       long        neighborhood
# 0  POINT (-79.98570 40.44658) -79.985699  40.446583    Crawford-Roberts
# 1  POINT (-80.03249 40.47296) -80.032487  40.472955  Marshall-Shadeland
# 2  POINT (-79.92074 40.39394) -79.920739  40.393940       New Homestead
# 3  POINT (-79.94616 40.46257) -79.946165  40.462570          Bloomfield
# 4  POINT (-79.92767 40.47768) -79.927670  40.477683       Highland Park
#
# [5 rows x 27 columns]

# %%
grph = parks["neighborhood"].value_counts().sort_index().plot(kind='bar', rot=90,figsize =(15,10),legend = True)

# %%
num_parks = parks.groupby("neighborhood").sum("acreage")

parks_map = neighborhoods.merge(num_parks, how='left', left_on='hood', right_on='neighborhood')

parks_map[['hood','acreage','geometry']].head()
# Out:
#                hood    acreage  \
# 0   Central Oakland   1.844071
# 1     North Oakland   0.258574
# 2      West Oakland   0.053646
# 3  Crawford-Roberts   2.120504
# 4    Strip District  41.615985
#
#                                             geometry
# 0  POLYGON ((-79.95304 40.44203, -79.95302 40.442...
# 1  POLYGON ((-79.95455 40.45882, -79.95427 40.458...
# 2  POLYGON ((-79.96230 40.44294, -79.96220 40.442...
# 3  POLYGON ((-79.98275 40.44641, -79.98273 40.446...
# 4  POLYGON ((-79.97494 40.45629, -79.97484 40.456...

# %%
map = parks.plot(column='acreage')

# %%
data = parks.drop_duplicates(subset = "neighborhood").sort_index().plot(kind='bar', rot=90,figsize =(15,10),legend = True, x = "neighborhood", y = "acreage")
#graph = data.plot(kind='bar', rot=90,figsize =(15,10),legend = True, x = "neighborhood", y = "acreage")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-f3eaf9b82f0f> in <module>
# ----> 1 data = parks.drop_duplicates(subset = "neighborhood").sort_index().plot(kind='bar', rot=90,figsize =(15,10),legend = True, x = "neighborhood", y = "acreage")
#       2 #graph = data.plot(kind='bar', rot=90,figsize =(15,10),legend = True, x = "neighborhood", y = "acreage")
#
# /opt/tljh/user/lib/python3.8/site-packages/geopandas/geodataframe.py in plot(self, *args, **kwargs)
#     897         from there.
#     898         """
# --> 899         return plot_dataframe(self, *args, **kwargs)
#     900
#     901     plot.__doc__ = plot_dataframe.__doc__
#
# /opt/tljh/user/lib/python3.8/site-packages/geopandas/plotting.py in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     613
#     614     if column is None:
# --> 615         return plot_series(
#     616             df.geometry,
#     617             cmap=cmap,
#
# /opt/tljh/user/lib/python3.8/site-packages/geopandas/plotting.py in plot_series(s, cmap, color, ax, figsize, aspect, **style_kwds)
#     411
#     412         values_ = values[poly_idx] if cmap else None
# --> 413         _plot_polygon_collection(
#     414             ax, polys, values_, facecolor=facecolor, cmap=cmap, **style_kwds
#     415         )
#
# /opt/tljh/user/lib/python3.8/site-packages/geopandas/plotting.py in _plot_polygon_collection(ax, geoms, values, color, cmap, vmin, vmax, **kwargs)
#     144     _expand_kwargs(kwargs, multiindex)
#     145
# --> 146     collection = PatchCollection([PolygonPatch(poly) for poly in geoms], **kwargs)
#     147
#     148     if values is not None:
#
# /opt/tljh/user/lib/python3.8/site-packages/matplotlib/collections.py in __init__(self, patches, match_original, **kwargs)
#    1832             kwargs['antialiaseds'] = [p.get_antialiased() for p in patches]
#    1833
# -> 1834         Collection.__init__(self, **kwargs)
#    1835
#    1836         self.set_paths(patches)
#
# /opt/tljh/user/lib/python3.8/site-packages/matplotlib/collections.py in __init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, offset_position, zorder, **kwargs)
#     162
#     163         self._path_effects = None
# --> 164         self.update(kwargs)
#     165         self._paths = None
#     166
#
# /opt/tljh/user/lib/python3.8/site-packages/matplotlib/artist.py in update(self, props)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# /opt/tljh/user/lib/python3.8/site-packages/matplotlib/artist.py in <listcomp>(.0)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# /opt/tljh/user/lib/python3.8/site-packages/matplotlib/artist.py in _update_property(self, k, v)
#     999                 func = getattr(self, 'set_' + k, None)
#    1000                 if not callable(func):
# -> 1001                     raise AttributeError('{!r} object has no property {!r}'
#    1002                                          .format(type(self).__name__, k))
#    1003                 return func(v)
#
# AttributeError: 'PatchCollection' object has no property 'kind'
